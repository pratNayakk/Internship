# %% [markdown]
#  1. Write a python program which searches all the product under a particular product from www.amazon.in.
# The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search
# for guitars.

# %% [markdown]
# 3. Write a python program to access the search bar and search button on images.google.com and scrape 10
# images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
Sir left Question no 1 and 2 because in my system when i write input

# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# C:\Users\prath\AppData\Local\Temp/ipykernel_7604/437299702.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
url = "https://images.google.com/"

driver.get(url)
search_bar = driver.find_element(By.XPATH,'//*[@id="sbtc"]/div/div[2]/input')

search_bar.send_keys("cakes")

# %%
search_bot = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button")
search_bot
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="0688fccc20a93dda86528e26197e085f", element="1466ac92-6b3a-4d54-80e3-a5a36f3de549")>

# %%
search_bot.click()

# %%
img_cake = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
len(img_cake)
# Out:
# 48

# %%
img = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in img:
    print(i.get_attribute("src"))
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT8UuxGi_Fgp4KYLmsq6UV4J5htjlTXM5GUeA&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSAbySpjw_YpYg_JEce4JHjkOTOPApdjG197Q&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSt0K1iLAfz0W2NeZk0OW_Orah2AlvzURw8Tw&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSUaa-dtcO3mYHoBwmqX6CNZKEh9HkuCGKyLQ&usqp=CAU
# ...

# %%
driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# C:\Users\prath\AppData\Local\Temp/ipykernel_7604/437299702.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
url = "https://images.google.com/"

driver.get(url)
search_bar = driver.find_element(By.XPATH,'//*[@id="sbtc"]/div/div[2]/input')

search_bar.send_keys("fruits")

# %%
search_bot = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button")
search_bot
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2f6dfbf22f060de27f8a53cef4723208", element="08fc79aa-53ee-4078-b68c-70871b57d4c5")>

# %%
search_bot.click()

# %%
img_fruit = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
len(img_fruit)
# Out:
# 48

# %%
img = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in img:
    print(i.get_attribute("src"))
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT8UuxGi_Fgp4KYLmsq6UV4J5htjlTXM5GUeA&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSAbySpjw_YpYg_JEce4JHjkOTOPApdjG197Q&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSt0K1iLAfz0W2NeZk0OW_Orah2AlvzURw8Tw&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSUaa-dtcO3mYHoBwmqX6CNZKEh9HkuCGKyLQ&usqp=CAU
# ...

# %% [markdown]
# 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be
# scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# C:\Users\prath\AppData\Local\Temp/ipykernel_7604/437299702.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
url = 'https://www.flipkart.com/search?q=smartphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
driver.get(url)

# %%
Brand_Name = []
BName=driver.find_elements(By.XPATH,"//div[@class='_4rR01T']")
for i in BName:
    if i.text is None :
        Brand_Name.append("--") 
    else:
        Brand_Name.append(i.text)
print(len(Brand_Name))
print(Brand_Name)
# Out:
# 24
# ['REDMI 9i Sport (Coral Green, 64 GB)', 'REDMI 10 (Pacific Blue, 64 GB)', 'Infinix HOT 12 Play (Daylight Green, 64 GB)', 'I Kall Z10 (Grey, 64 GB)', 'Infinix HOT 12 Play (Horizon Blue, 64 GB)', 'realme C31 (Light Silver, 32 GB)', 'APPLE iPhone 12 (Black, 128 GB)', 'I Kall Z5 (Blue, 16 GB)', 'REDMI 10 (Midnight Black, 64 GB)', 'Infinix HOT 12 Play (Racing Black, 64 GB)', 'realme C31 (Dark Green, 32 GB)', 'I Kall Z8 Star (Grey, 16 GB)', 'realme Narzo 50i (Mint Green, 64 GB)', 'realme Narzo 50i (Carbon Black, 32 GB)', 'realme Narzo 50i (Mint Green, 32 GB)', 'I Kall K440 (Cyan, 64 GB)', 'realme C31 (Dark Green, 64 GB)', 'REDMI 10 (Caribbean Green, 64 GB)', 'REDMI 9i Sport (Carbon Black, 64 GB)', 'I Kall Z4 Pro (Grey, 32 GB)', 'REDMI 9i Sport (Metallic Blue, 64 GB)', 'REDMI Note 10T 5G (Mint Green, 128 GB)', 'realme C21Y (Cross Blue, 32 GB)', 'I Kall Z1 Ultra Series (Dark Blue, 32 GB)']

# %%
Storage_RAM = []
ram=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[1]")
for i in ram:
    if i.text is None :
        Storage_RAM.append("--") 
    else:
        Storage_RAM.append(i.text)
print(len(Storage_RAM))
print(Storage_RAM)
# Out:
# 24
# ...

# %%
Camera = []
C=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[3]")
for i in C:
    if i.text is None :
        Camera.append("--") 
    else:
        Camera.append(i.text)
print(len(Camera))
print(Camera)
# Out:
# 24
# ['13MP Rear Camera | 5MP Front Camera', '50MP + 2MP | 5MP Front Camera', '13MP + Depth Lens | 8MP Front Camera', '20MP Rear Camera | 13MP Front Camera', '13MP + Depth Lens | 8MP Front Camera', '13MP + 2MP + 0.3MP | 5MP Front Camera', '12MP + 12MP | 12MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '50MP + 2MP | 5MP Front Camera', '13MP + Depth Lens | 8MP Front Camera', '13MP + 2MP + 0.3MP | 5MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '20MP Rear Camera | 13MP Front Camera', '13MP + 2MP + 0.3MP | 5MP Front Camera', '50MP + 2MP | 5MP Front Camera', '13MP Rear Camera | 5MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '13MP Rear Camera | 5MP Front Camera', '48MP Primary Camera + 2MP Macro Lens + 2MP Depth Sensor | 8MP Front Camera', '13MP + 2MP + 2MP | 5MP Front Camera', '8MP Rear Camera | 5MP Front Camera']

# %%
Display = []
D=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[2]")
for i in D:
    if i.text is None :
        Display.append("--") 
    else:
        Display.append(i.text)
print(len(Display))
print(Display)
# Out:
# 24
# ['16.59 cm (6.53 inch) HD+ Display', '17.02 cm (6.7 inch) HD+ Display', '17.32 cm (6.82 inch) HD+ Display', '16.59 cm (6.53 inch) HD+ Display', '17.32 cm (6.82 inch) HD+ Display', '16.56 cm (6.52 inch) HD Display', '15.49 cm (6.1 inch) Super Retina XDR Display', '13.84 cm (5.45 inch) Display', '17.02 cm (6.7 inch) HD+ Display', '17.32 cm (6.82 inch) HD+ Display', '16.56 cm (6.52 inch) HD Display', '13.84 cm (5.45 inch) Display', '16.51 cm (6.5 inch) Display', '16.51 cm (6.5 inch) Display', '16.51 cm (6.5 inch) Display', '16.59 cm (6.53 inch) Display', '16.56 cm (6.52 inch) HD Display', '17.02 cm (6.7 inch) HD+ Display', '16.59 cm (6.53 inch) HD+ Display', '13.84 cm (5.45 inch) Display', '16.59 cm (6.53 inch) HD+ Display', '16.66 cm (6.56 inch) Full HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '13.97 cm (5.5 inch) Display']

# %%
Processor = []
P=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[5]")
for i in P:
    if i.text is None :
        Processor.append("--") 
    else:
        Processor.append(i.text)
print(len(Processor))
print(Processor)
# Out:
# 24
# ['MediaTek Helio G25 Processor', 'Qualcomm Snapdragon 680 Processor', 'Unisoc T610 Processor', '1 year manufacturing warranty for mobile and 6 months for box accessories', 'Unisoc T610 Processor', 'Unisoc T612 Processor', 'Ceramic Shield', '1 year manufacturing warranty for mobile and 6 months for box accessories', 'Qualcomm Snapdragon 680 Processor', 'Unisoc T610 Processor', 'Unisoc T612 Processor', '1 year manufacturing warranty for mobile and 6 months for box accessories', 'SC9863A Processor', 'SC9863A Processor', 'SC9863A Processor', '1 year manufacturing warranty for mobile and 6 months for box accessories', 'Unisoc T612 Processor', 'Qualcomm Snapdragon 680 Processor', 'MediaTek Helio G25 Processor', '1 year manufacturing warranty for mobile and 6 months for box accessories', 'MediaTek Helio G25 Processor', 'Mediatek Dimensity 700 Processor', 'Unisoc T610 Processor', '1 year manufacturing warranty for mobile and 6 months for box accessories']

# %%
Battery = []
B=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[4]")
for i in B:
    if i.text is None :
        Battery.append("--") 
    else:
        Battery.append(i.text)
print(len(Battery))
print(Battery)
# Out:
# 24
# ['5000 mAh Li-Polymer Battery', '6000 mAh Lithium Polymer Battery', '6000 mAh Li-ion Polymer Battery', '5000 mAh Battery', '6000 mAh Li-ion Polymer Battery', '5000 mAh Battery', 'A14 Bionic Chip with Next Generation Neural Engine Processor', '3000 mAh Battery', '6000 mAh Lithium Polymer Battery', '6000 mAh Li-ion Polymer Battery', '5000 mAh Battery', '2800 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '5000 mAh Battery', '6000 mAh Lithium Polymer Battery', '5000 mAh Li-Polymer Battery', '3000 mAh Battery', '5000 mAh Li-Polymer Battery', '5000 mAh Lithium Polymer Battery', '5000 mAh Battery', '3000 mAh Battery']

# %%
Price = []
price=driver.find_elements(By.XPATH,"//div[@class='_30jeq3 _1_WHN1']")
for i in price:
    if i.text is None :
        Price.append("--") 
    else:
        Price.append(i.text)
print(len(Price))
print(Price)
# Out:
# 24
# ['₹8,799', '₹9,999', '₹8,499', '₹7,999', '₹8,499', '₹8,999', '₹56,999', '₹4,699', '₹9,999', '₹8,499', '₹8,999', '₹4,699', '₹8,999', '₹7,499', '₹7,499', '₹7,599', '₹9,999', '₹9,999', '₹8,799', '₹4,999', '₹8,799', '₹13,999', '₹9,499', '₹4,999']

# %%
df = pd.DataFrame({'Brand_Name': Brand_Name,'Storage_RAM_ROM': Storage_RAM, 'Display_size_Resolution': Display,'Camera': Camera,'Processor And Cores': Processor,'Battery': Battery,'Price': Price})
df
# Out:
#                                      Brand_Name  \
# 0           REDMI 9i Sport (Coral Green, 64 GB)
# 1                REDMI 10 (Pacific Blue, 64 GB)
# 2   Infinix HOT 12 Play (Daylight Green, 64 GB)
# 3                      I Kall Z10 (Grey, 64 GB)
# 4     Infinix HOT 12 Play (Horizon Blue, 64 GB)
# 5              realme C31 (Light Silver, 32 GB)
# 6               APPLE iPhone 12 (Black, 128 GB)
# 7                       I Kall Z5 (Blue, 16 GB)
# 8              REDMI 10 (Midnight Black, 64 GB)
# 9     Infinix HOT 12 Play (Racing Black, 64 GB)
# 10               realme C31 (Dark Green, 32 GB)
# 11                 I Kall Z8 Star (Grey, 16 GB)
# 12         realme Narzo 50i (Mint Green, 64 GB)
# 13       realme Narzo 50i (Carbon Black, 32 GB)
# 14         realme Narzo 50i (Mint Green, 32 GB)
# 15                    I Kall K440 (Cyan, 64 GB)
# 16               realme C31 (Dark Green, 64 GB)
# 17            REDMI 10 (Caribbean Green, 64 GB)
# ...

# %% [markdown]
# 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google
# maps.

# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
import re

# %%
driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# C:\Users\prath\AppData\Local\Temp/ipykernel_7604/437299702.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
wait = WebDriverWait(driver, 10)
driver.get("https://www.google.com/maps")

# %%
search = driver.find_element(By.ID,"searchboxinput")

# %%
search.send_keys("Dwarka")

# %%
bot = driver.find_element(By.ID,"searchbox-searchbutton")

# %%
bot.click()

# %%
url = driver.current_url
print("URL Extracted: ", url)
# Out:
# URL Extracted:  https://www.google.com/maps/place/Dwarka,+Gujarat/@22.2467142,68.951884,14z/data=!3m1!4b1!4m5!3m4!1s0x39569c266399e37b:0xb5866e461a106e0a!8m2!3d22.2441975!4d68.9684562

# %%
geospatial coordinates = re.findall(r'@(.*)/data',url)

# %%
geospatial coordinates
# Out:
# ['22.2467142,68.951884,14z']

# %% [markdown]
# 6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21)
# from trak.in.

# %%
driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# C:\Users\prath\AppData\Local\Temp/ipykernel_7604/437299702.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
url = 'https://trak.in/india-startup-funding-investment-2015/'
driver.get(url)

# %%
date = driver.find_elements(By.XPATH,'//td[@class="column-2"]')
len(date)
# Out:
# 392

# %%
Date=[]

for i in date[5:29]:
    Date.append(i.text)
Date
# Out:
# ['04/03/2021',
#  '31/03/2021',
#  '30/03/2021',
#  '30/03/2021',
#  '23/03/2021',
#  '25/03/2021',
#  '26/03/2021',
#  '11/02/2021',
#  '22/02/2021',
#  '19/02/2021',
#  '17/02/2021',
#  '15/02/2021',
#  '12/02/2021',
#  '12/02/2021',
#  '09/02/2021',
#  '09/02/2021',
#  '15/01/2021',
#  '28/01/2021',
#  '19/01/2021',
#  '19/01/2021',
#  '18/01/2021',
#  '18/01/2021',
#  '11/01/2021',
#  '13/01/2021']

# %%
name = driver.find_elements(By.XPATH,'//td[@class="column-3"]')
len(name)
# Out:
# 392

# %%
Name=[]

for i in name[5:29]:
    Name.append(i.text)
Name
# Out:
# ['DealShare',
#  'Uniphore',
#  'Dunzo',
#  'BYJU’S',
#  'SkilloVilla',
#  'CityMall',
#  'DotPe',
#  'Doubtnut',
#  'Zomato',
#  'Fingerlix',
#  'Zolve',
#  'KreditBee',
#  'Pepperfry',
#  'Grofers',
#  'Nothing',
#  'SplashLearn',
#  'Digit Insurance',
#  'Bombay Shaving Company',
#  'DeHaat',
#  'Darwinbox',
#  'mfine',
#  'Udayy',
#  'True Elements',
#  'Saveo']

# %%
ind = driver.find_elements(By.XPATH,'//td[@class="column-4"]')
len(ind)
# Out:
# 392

# %%
Ind=[]

for i in ind[5:29]:
    Ind.append(i.text)
Ind
# Out:
# ['E-commerce',
#  'Technology',
#  'E-commerce',
#  'Edu-tech',
#  'Edu-tech',
#  'E-commerce',
#  'FinTech',
#  'Edu Tech',
#  'Hospitality',
#  'Hospitality',
#  'FinTech',
#  'Finance',
#  'E-commerce',
#  'E-Commerce',
#  'Technology',
#  'EdTech',
#  'Financial Services',
#  'Consumer Goods Company',
#  'AgriTech Startup',
#  'SaaS',
#  'Health Tech Startup',
#  'EdTech',
#  'Food Startup',
#  'B2B E-commerce']

# %%
loc = driver.find_elements(By.XPATH,'//td[@class="column-5"]')
len(loc)
# Out:
# 392

# %%
Sub=[]

for i in loc[5:29]:
    Sub.append(i.text)
Sub
# Out:
# ['Online shopping platform',
#  'Conversational Service Automation (CSA)',
#  'Hyper-local delivery app',
#  'Online tutoring',
#  'Career and job-oriented upskilling.',
#  'Social ecommerce and online grocery platform',
#  'Commerce and payments platform to offline enterprise businesses.',
#  'E-Learning Platform',
#  'Online Food Delivery Platform',
#  'Semi-cooked food delivery app',
#  'Global Neobank Venture',
#  'Digital lending platform',
#  'Multi-brand furniture brand',
#  'Online supermarket',
#  'Consumer Technology Venture',
#  'Game-based learning programme',
#  'Insurance Services',
#  'Shave care, beard care, and skincare products',
#  'online marketplace for farm products and services',
#  'HR Tech',
#  'AI-powered telemedicine mobile app',
#  'Online learning platform for kids in class 1-5',
#  'Whole Food plant based Nashta',
#  'Pharmacies']

# %%
Loc=[]

for i in driver.find_elements(By.XPATH,'//td[@class="column-6"]')[5:29]:
    Loc.append(i.text)
Loc
# Out:
# ['Jaipur, Rajasthan',
#  'Palo Alto',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Gurgaon',
#  'Gurgaon',
#  'Gurgaon',
#  'Gurgaon',
#  'Mumbai',
#  'Mumbai',
#  'Bengaluru',
#  'Mumbai',
#  'Gurgaon',
#  'London',
#  'Gurgaon',
#  'Bengaluru',
#  'New Delhi',
#  'Patna',
#  'Mumbai',
#  'Bengaluru',
#  'Gurgaon',
#  'Pune',
#  'Bengaluru']

# %%
Inv=[]

for i in driver.find_elements(By.XPATH,'//td[@class="column-7"]')[5:29]:
    Inv.append(i.text)
Inv
# Out:
# ['Innoven Capital',
#  'Sorenson Capital Partners',
#  'Krishtal Advisors Pte Ltd',
#  'MC Global Edtech, B Capital, Baron, others',
#  'Titan Capital, others',
#  'Accel Partners',
#  'PayU',
#  'SIG Global, Sequoia Capital, WaterBridge Ventures and ON Mauritius',
#  'Tiger Global, Kora',
#  'Rhodium Trust, Accel Partners and Swiggy',
#  'Accel Partners and Lightspeed Venture Partners',
#  'Azim Premji’s PremjiInvest and South Korea’s Mirae Asset Venture',
#  'InnoVen Capital',
#  'SoftBank Vision Fund (SVF)',
#  'GV',
#  'Owl Ventures',
#  'A91 Partners, Faering Capital, TVS Capital Funds',
#  'Reckitt Benckiser',
#  'Prosus Ventures',
#  'Salesforce Ventures',
#  'Heritas Capital Management',
#  'Sequoia Capital',
#  'SIDBI Venture Capital',
#  'Matrix Partners India, RTP Global, others']

# %%
t=[]

for i in driver.find_elements(By.XPATH,'//td[@class="column-8"]')[5:29]:
    t.append(i.text)
t
# Out:
# ['Debt Financing',
#  'Series D',
#  'Series E',
#  'Series F',
#  'Seed',
#  'Series A',
#  'Series A',
#  'Series B',
#  'Venture',
#  'Series C',
#  'Seed',
#  'Series C',
#  'Debt Financing',
#  'Unspecified',
#  'Series A',
#  'Series C',
#  'Venture',
#  'Venture',
#  'Series C',
#  'Seed',
#  'Venture Round',
#  'Seed Funding',
#  'Series',
#  'Seed']

# %%
at=[]

for i in driver.find_elements(By.XPATH,'//td[@class="column-9"]')[5:29]:
    at.append(i.text)
at
# Out:
# ['250,000,000',
#  '140,000,000',
#  '8,000,000',
#  '460,000,000',
#  '300,000,000',
#  '11,000,000',
#  '27,500,000',
#  '2,500,000',
#  '250,000,000',
#  '2,747,045.20',
#  '1,50,00,000',
#  '75,000,000',
#  '4,773,958',
#  '55,000,000',
#  '15,000,000',
#  '18,000,000',
#  '1,80,00,000',
#  '6,172,258.50',
#  '30,000,000',
#  '15,000,000',
#  '16,000,000',
#  '15,000,000',
#  '100,000,000',
#  '4,000,000']

# %%
df = pd.DataFrame({'Date':Date,'Start up(Name)':Name,'Industry':Ind,'Sub-Vertical':Sub,'Location':Loc,'Investor Name':Inv,'Investment Type':t,'Amount':at})
df
# Out:
#           Date          Start up(Name)                Industry  \
# 0   04/03/2021               DealShare              E-commerce
# 1   31/03/2021                Uniphore              Technology
# 2   30/03/2021                   Dunzo              E-commerce
# 3   30/03/2021                  BYJU’S                Edu-tech
# 4   23/03/2021             SkilloVilla                Edu-tech
# 5   25/03/2021                CityMall              E-commerce
# 6   26/03/2021                   DotPe                 FinTech
# 7   11/02/2021                Doubtnut                Edu Tech
# 8   22/02/2021                  Zomato             Hospitality
# 9   19/02/2021               Fingerlix             Hospitality
# 10  17/02/2021                   Zolve                 FinTech
# 11  15/02/2021               KreditBee                 Finance
# 12  12/02/2021               Pepperfry              E-commerce
# 13  12/02/2021                 Grofers              E-Commerce
# ...

# %% [markdown]
# 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be
# scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# C:\Users\prath\AppData\Local\Temp/ipykernel_7604/437299702.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
url = 'https://www.forbes.com/billionaires/'
driver.get(url)

# %%
Name=[]

for i in driver.find_elements(By.XPATH,'//div[@class="personName"]'):
    Name.append(i.text)
Name
# Out:
# ['Elon Musk',
#  'Jeff Bezos',
#  'Bernard Arnault & family',
#  'Bill Gates',
#  'Warren Buffett',
#  'Larry Page',
#  'Sergey Brin',
#  'Larry Ellison',
#  'Steve Ballmer',
#  'Mukesh Ambani',
#  'Gautam Adani & family',
#  'Michael Bloomberg',
#  'Carlos Slim Helu & family',
#  'Francoise Bettencourt Meyers & family',
#  'Mark Zuckerberg',
#  'Jim Walton',
#  'Zhong Shanshan',
#  'Alice Walton',
#  'Rob Walton',
#  'Changpeng Zhao',
#  'Charles Koch',
#  'Julia Koch & family',
#  'Amancio Ortega',
#  'Michael Dell',
#  'Zhang Yiming',
#  'David Thomson & family',
#  'Phil Knight & family',
#  'Dieter Schwarz',
#  'Robin Zeng',
#  'MacKenzie Scott',
#  'Rodolphe Saadé & family',
#  'François Pinault & family',
#  'Klaus-Michael Kuehne',
#  'Ma Huateng',
#  'Beate Heister & Karl Albrecht Jr. & family',
#  'Giovanni Ferrero',
#  'Li Ka-shing',
#  'Stephen Schwarzman',
#  'Lee Shau Kee',
#  'Len Blavatnik',
#  'Jacqueline Mars',
#  'John Mars',
#  'Alain Wertheimer',
# ...

# %%
Net=[]

for i in driver.find_elements(By.XPATH,'//div[@class="netWorth"]'):
    Net.append(i.text)
Net
# Out:
# ['$219 B',
#  '$171 B',
#  '$158 B',
#  '$129 B',
#  '$118 B',
#  '$111 B',
#  '$107 B',
#  '$106 B',
#  '$91.4 B',
#  '$90.7 B',
#  '$90 B',
#  '$82 B',
#  '$81.2 B',
#  '$74.8 B',
#  '$67.3 B',
#  '$66.2 B',
#  '$65.7 B',
#  '$65.3 B',
#  '$65 B',
#  '$65 B',
#  '$60 B',
#  '$60 B',
#  '$59.6 B',
#  '$55.1 B',
#  '$50 B',
#  '$49.2 B',
#  '$47.3 B',
#  '$47.1 B',
#  '$44.8 B',
#  '$43.6 B',
#  '$41.4 B',
#  '$40.4 B',
#  '$37.3 B',
#  '$37.2 B',
#  '$36.8 B',
#  '$36.2 B',
#  '$34.8 B',
#  '$34.8 B',
#  '$32.6 B',
#  '$32.5 B',
#  '$31.7 B',
#  '$31.7 B',
#  '$31.2 B',
#  '$31.2 B',
#  '$30.8 B',
#  '$30.2 B',
#  '$28.7 B',
#  '$28.6 B',
#  '$28.3 B',
#  '$27.5 B',
#  '$27.4 B',
#  '$27.3 B',
#  '$27.2 B',
#  '$26.1 B',
#  '$25.2 B',
#  '$24.3 B',
#  '$24.3 B',
#  '$24.3 B',
#  '$24.1 B',
#  '$24 B',
#  '$23.9 B',
#  '$23.7 B',
#  '$23.5 B',
#  '$23.2 B',
#  '$23.1 B',
#  '$23 B',
#  '$22.8 B',
#  '$22.8 B',
#  '$22.3 B',
#  '$22.1 B',
#  '$22 B',
#  '$22 B',
#  '$21.8 B',
# ...

# %%
con=[]

for i in driver.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]'):
    con.append(i.text)
con
# Out:
# ['United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'India',
#  'India',
#  'United States',
#  'Mexico',
#  'France',
#  'United States',
#  'United States',
#  'China',
#  'United States',
#  'United States',
#  'Canada',
#  'United States',
#  'United States',
#  'Spain',
#  'United States',
#  'China',
#  'Canada',
#  'United States',
#  'Germany',
#  'Hong Kong',
#  'United States',
#  'France',
#  'France',
#  'Germany',
#  'China',
#  'Germany',
#  'Italy',
#  'Hong Kong',
#  'United States',
#  'Hong Kong',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'France',
#  'Mexico',
#  'Australia',
#  'India',
#  'United States',
#  'China',
#  'United States',
#  'Austria',
#  'Italy',
#  'United States',
#  'Japan',
#  'China',
#  'Germany',
#  'India',
#  'China',
#  'China',
#  'United States',
#  'Japan',
#  'China',
# ...

# %%
src=[]

for i in driver.find_elements(By.XPATH,'//div[@class="source-column"]'):
    src.append(i.text)
src
# Out:
# ['Tesla, SpaceX',
#  'Amazon',
#  'LVMH',
#  'Microsoft',
#  'Berkshire Hathaway',
#  'Google',
#  'Google',
#  'software',
#  'Microsoft',
#  'diversified',
#  'infrastructure, commodities',
#  'Bloomberg LP',
#  'telecom',
#  "L'Oréal",
#  'Facebook',
#  'Walmart',
#  'beverages, pharmaceuticals',
#  'Walmart',
#  'Walmart',
#  'cryptocurrency exchange',
#  'Koch Industries',
#  'Koch Industries',
#  'Zara',
#  'Dell computers',
#  'TikTok',
#  'media',
#  'Nike',
#  'retail',
#  'batteries',
#  'Amazon',
#  'shipping',
#  'luxury goods',
#  'shipping',
#  'internet media',
#  'supermarkets',
#  'Nutella, chocolates',
#  'diversified',
#  'investments',
#  'real estate',
#  'music, chemicals',
#  'candy, pet food',
#  'candy, pet food',
#  'Chanel',
#  'Chanel',
#  'mining',
#  'mining',
#  'software services',
#  'hedge funds',
#  'home appliances',
#  'casinos',
#  'Red Bull',
#  'eyeglasses',
#  'hedge funds',
#  'fashion retail',
#  'online games',
#  'BMW, pharmaceuticals',
# ...

# %%
ind=[]

for i in driver.find_elements(By.XPATH,'//div[@class="category"]'):
    ind.append(i.text)
ind
# Out:
# ['Automotive',
#  'Technology',
#  'Fashion & Retail',
#  'Technology',
#  'Finance & Investments',
#  'Technology',
#  'Technology',
#  'Technology',
#  'Technology',
#  'Diversified',
#  'Diversified',
#  'Media & Entertainment',
#  'Telecom',
#  'Fashion & Retail',
#  'Technology',
#  'Fashion & Retail',
#  'Food & Beverage',
#  'Fashion & Retail',
#  'Fashion & Retail',
#  'Finance & Investments',
#  'Diversified',
#  'Diversified',
#  'Fashion & Retail',
#  'Technology',
#  'Media & Entertainment',
#  'Media & Entertainment',
#  'Fashion & Retail',
#  'Fashion & Retail',
#  'Automotive',
#  'Technology',
#  'Logistics',
#  'Fashion & Retail',
#  'Logistics',
#  'Technology',
#  'Fashion & Retail',
#  'Food & Beverage',
#  'Diversified',
#  'Finance & Investments',
#  'Real Estate',
#  'Diversified',
#  'Food & Beverage',
#  'Food & Beverage',
#  'Fashion & Retail',
#  'Fashion & Retail',
#  'Metals & Mining',
#  'Metals & Mining',
#  'Technology',
#  'Finance & Investments',
# ...

# %%
df = pd.DataFrame({'NAME':Name,'NET WORTH':Net,'COUNTRY / TERRITORY':con,'SOURCE':src,'INDUSTRY':ind})
df
# Out:
#                          NAME NET WORTH COUNTRY / TERRITORY  \
# 0                   Elon Musk    $219 B       United States
# 1                  Jeff Bezos    $171 B       United States
# 2    Bernard Arnault & family    $158 B              France
# 3                  Bill Gates    $129 B       United States
# 4              Warren Buffett    $118 B       United States
# ..                        ...       ...                 ...
# 195    Marcel Herrmann Telles   $10.3 B              Brazil
# 196                Leon Black     $10 B       United States
# 197                Joe Gebbia     $10 B       United States
# 198              David Geffen     $10 B       United States
# 199                Yu Renrong     $10 B               China
#
#                     SOURCE               INDUSTRY
# 0            Tesla, SpaceX             Automotive
# 1                   Amazon             Technology
# 2                     LVMH       Fashion & Retail
# ...

# %% [markdown]
# 7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# C:\Users\prath\AppData\Local\Temp/ipykernel_7604/437299702.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
url = 'https://www.digit.in/top-products/best-gaming-laptops-40.html'
driver.get(url)

# %%
bra=driver.find_elements(By.XPATH,"//div[@class='TopNumbeHeading active sticky-footer']")
len(bra)
# Out:
# 10

# %%
Brands = []
for i in bra:
    Brands.append(str(i.text).replace("\n",""))
Brands
# Out:
# ['1.MSI TITAN GT77-12UHS',
#  '2.ALIENWARE X17 R2',
#  '3.ACER PREDATOR TRITON 500 SE PT516-52S',
#  '4.OMEN BY HP (16-B1371TX)',
#  '5.ACER PREDATOR HELIOS 300 AN515-45 (NH.QBRSI.0',
#  '6.MSI DELTA 15 (A5EFK-083IN)',
#  '7.OMEN BY HP (16-C0141AX)',
#  '8.LENOVO LEGION 5I PRO (82RF00MGIN)',
#  '9.ALIENWARE M15 R5 RYZEN EDITION ICC-C780001WIN',
#  '10.LENOVO SLIM 7 GEN 6 (82K8002JIN)']

# %%
spec=driver.find_elements(By.XPATH,"//div[@class='Specs-Wrap']")
len(spec)
# Out:
# 10

# %%
Specification = []
for i in spec:
    Specification.append(str(i.text).replace("\n",""))
Specification
# Out:
# ['WINDOWS 11 HOME OS17.3" (3840 X 2160) DISPLAY12TH GEN INTEL CORE I9-12900HX | NA PROCESSOR2 TB SSD/64 GB DDR5 MEMORY',
#  'WINDOWS 11 HOME OS17.3" (1920X1080) DISPLAY12TH GEN INTEL CORE I9-12900HK | 5.00 GHZ PROCESSOR1 TB SSD/32 GB DDR5 MEMORY',
#  'WINDOWS 11 HOME OS16" (2560 X 1600) DISPLAY12TH GEN INTEL CORE I7-12700H | 3.50 GHZ PROCESSOR2 TB SSD/32 GB DDR5 MEMORY',
#  'WINDOWS 11 HOME OS16.1" (2560 X 1440) DISPLAY12TH GEN INTEL CORE I7-12700H | 4.7 GHZ PROCESSOR1 TB SSD/8 GB DDR5 MEMORY',
#  'WINDOWS 11 HOME OS15.6" (2560 X 1440) DISPLAYAMD RYZEN 9-5900HX | NA PROCESSOR512 GB SSD/16 GB DDR4 MEMORY',
#  'WINDOWS 11 HOME OS15.6" (1920 X 1080) DISPLAYAMD 5TH GEN RYZEN 9-5900HX | 3.3GHZ PROCESSOR1 TB SSD/16 GB DDR4 MEMORY',
#  'WINDOWS 11 HOME OS16.1" (2560 X 1440) DISPLAYAMD RYZEN™ 9 5900HX | 3.3 GHZ PROCESSOR1 TB NVME/16 GB DDR4 MEMORY',
#  'WINDOWS 11 HOME OS16" (2560 X 1600) DISPLAY12TH GEN INTEL CORE I7-12700H | 3.50 GHZ PROCESSOR1 TB SSD/16 GB DDR5 MEMORY',
# ...

# %%
des=driver.find_elements(By.XPATH,"//div[@class='Section-center']")
len(des)
# Out:
# 10

# %%
Products_Description = []
for i in des:
    Products_Description.append(str(i.text).replace("\n",""))
Products_Description
# Out:
# ['The very best MSI gaming laptop featuring an Intel processor is the MSI TITAN GT77 - 12UHS. This is the top of the line model from MSI’s recent refresh of their entire gaming lineup and is powered by the Intel Core i9-12900HX which is a 16 Core (8P+8E) processor that has 24 threads and a maximum Turbo power of 157 Watts. The graphics card in this laptop is the NVIDIA RTX 3080 Ti and it too sports a high TGP of 175 Watts. This is one of the most powerful CPU+GPU combinations with plenty of thermal headroom to allow it to operate at higher clock speeds for longer time periods. As for the memory, the MSI GT77-12UHS can have up to 128 GB of DDR5 memory but ships with 64 GB DDR5 clocked at 4800 MT/s. Being a 12th Gen machine also means that the motherboard has PCIe Gen 5.0 lanes for storage devices such as M.2 SSDs. The GT77-12UHS has four M.2 slots of which one slot is PCIe Gen 5 whereas the remaining three are PCIe Gen 4 slots. Then there’s also the display, the GT77-12UHS features a 
# ...

# %%
cost=driver.find_elements(By.XPATH,"//td[@class='smprice']")
len(cost)
# Out:
# 10

# %%
Price = []
for i in cost:
    Price.append(str(i.text).replace("\n",""))
Price
# Out:
# ['N/A',
#  '₹ 389,990',
#  '₹ 300,000',
#  '₹ 170,990',
#  '₹ 172,999',
#  '₹ 188,990',
#  '₹ 129,899',
#  '₹ 230,890',
#  '₹ 144,990',
#  '₹ 142,990']

# %%
df = pd.DataFrame({'Brands': Brands,'Specification':Specification,'Products_Description':Products_Description,'Price':Price})
df
# Out:
#                                             Brands  \
# 0                           1.MSI TITAN GT77-12UHS
# 1                               2.ALIENWARE X17 R2
# 2          3.ACER PREDATOR TRITON 500 SE PT516-52S
# 3                        4.OMEN BY HP (16-B1371TX)
# 4  5.ACER PREDATOR HELIOS 300 AN515-45 (NH.QBRSI.0
# 5                     6.MSI DELTA 15 (A5EFK-083IN)
# 6                        7.OMEN BY HP (16-C0141AX)
# 7              8.LENOVO LEGION 5I PRO (82RF00MGIN)
# 8  9.ALIENWARE M15 R5 RYZEN EDITION ICC-C780001WIN
# 9              10.LENOVO SLIM 7 GEN 6 (82K8002JIN)
#
#                                        Specification  \
# 0  WINDOWS 11 HOME OS17.3" (3840 X 2160) DISPLAY1...
# 1  WINDOWS 11 HOME OS17.3" (1920X1080) DISPLAY12T...
# 2  WINDOWS 11 HOME OS16" (2560 X 1600) DISPLAY12T...
# 3  WINDOWS 11 HOME OS16.1" (2560 X 1440) DISPLAY1...
# 4  WINDOWS 11 HOME OS15.6" (2560 X 1440) DISPLAYA...
# 5  WINDOWS 11 HOME OS15.6" (1920 X 1080) DISPLAYA...
# ...

# %% [markdown]
# 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted
# from any YouTube Video

# %%
driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# C:\Users\prath\AppData\Local\Temp/ipykernel_7604/437299702.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
url = 'https://www.youtube.com/watch?v=5Eqb_-j3FDA'
driver.get(url)

# %%
sp1=[]

for i in driver.find_elements(By.XPATH,'//yt-formatted-string[@class="style-scope ytd-comment-renderer"]')[0:500]:
    sp1.append((i.text).replace("\n",""))
len(sp1)
# Out:
# 500

# %%
sp1
# Out:
# ["Separated by Countries but united by music 🇮🇳🇵🇰Lot's of love from India 🇮🇳️",
#  'This song is highly addictive..love from India 🇮🇳',
#  'Addicted to this songLots of Love from INDIA🇮🇳🇮🇳🇵🇰',
#  "When this song was trending, i didn't like it but now I'm listening this on the loop mode...!!",
#  "I'm listening now but I'll listen for the whole of my life I love this song and also both of you voice from India 🇮🇳",
#  "I love all things of this song as music ,lyrics ,voice  but I can't understand all lyrics still this song won my heart",
#  'Ah when the subcontinent connects, mostly on music, it feels pure divine 🇮🇳🇧🇩🇵🇰',
#  'I came to know today that this singer is Pakistani, we just used to listen. Superb ️️',
#  'Only divided by border, but We are one  ️ love from india 🇮🇳',
#  'I dont listen songs but.....',
#  'There are some songs you just dont get enough of despite listening to it on repeat. This is one of those songs.',
# ...

# %%
t=[]

for i in driver.find_elements(By.XPATH,'//yt-formatted-string[@class="published-time-text style-scope ytd-comment-renderer"]')[0:500]:
    t.append((i.text).replace("\n",""))
len(t)
# Out:
# 500

# %%
t
# Out:
# ['3 months ago',
#  '1 day ago',
#  '5 hours ago',
#  '20 hours ago',
#  '17 hours ago',
#  '1 day ago',
#  '4 months ago',
#  '22 hours ago (edited)',
#  '1 day ago',
#  '1 hour ago',
#  '1 day ago (edited)',
#  '11 hours ago',
#  '2 months ago',
#  '20 hours ago (edited)',
#  '1 day ago (edited)',
#  '1 day ago',
#  '1 day ago',
#  '14 hours ago',
#  '1 month ago',
#  '1 day ago (edited)',
#  '2 months ago',
#  '4 months ago',
#  '2 days ago',
#  '20 hours ago',
#  '1 day ago',
#  '6 hours ago',
#  '2 days ago',
#  '14 hours ago',
#  '22 hours ago',
#  '22 hours ago',
#  '16 hours ago',
#  '4 months ago',
#  '17 hours ago',
#  '2 days ago (edited)',
#  '5 hours ago',
#  '2 days ago',
#  '22 hours ago',
#  '1 day ago',
#  '1 day ago',
#  '19 hours ago',
#  '3 months ago',
#  '1 month ago (edited)',
#  '6 hours ago',
#  '2 days ago',
#  '20 hours ago',
#  '3 months ago (edited)',
#  '14 hours ago',
#  '2 days ago',
#  '16 hours ago (edited)',
#  '2 days ago',
#  '15 hours ago',
# ...

# %%
u=[]

for i in driver.find_elements(By.XPATH,'//ytd-comment-action-buttons-renderer[@class="style-scope ytd-comment-renderer"]')[0:500]:
    u.append((i.text).replace("REPLY","").replace("\n",""))
len(u)
# Out:
# 500

# %%
u
# Out:
# ['2.8K',
#  '104',
#  '62',
#  '44',
#  '22',
#  '19',
#  '2.5K',
#  '57',
#  '28',
#  '7',
#  '81',
#  '10',
#  '6.1K',
#  '6',
#  '15',
#  '564',
#  '7',
#  '3',
#  '1.8K',
#  '15',
#  '1.6K',
#  '1.5K',
#  '316',
#  '3',
#  '11',
#  '4',
#  '11',
#  '10',
#  '51',
#  '5',
#  '2',
#  '1K',
#  '4',
#  '38',
#  '3',
#  '15',
#  '9',
#  '8',
#  '6',
#  '2',
#  '60K',
#  '1.7K',
#  '1',
#  '2',
#  '2',
#  '1.1K',
#  '1',
#  '223',
#  '1',
#  '3',
#  '1',
#  '530',
#  '6',
#  '2',
#  '1',
#  '4',
#  '2',
#  '1.4K',
#  '27',
#  '9',
#  '1',
#  '7',
#  '2',
#  '830',
#  '4',
#  '67',
#  '',
#  '5',
#  '2',
#  '386',
#  '4',
#  '15',
#  '2',
#  '8',
#  '',
#  '795',
#  '1',
#  '',
#  '3',
#  '',
#  '3.4K',
#  '2',
#  '171',
#  '3',
#  '11',
#  '',
#  '489',
#  '1',
#  '6',
#  '2',
#  '1',
#  '1',
#  '622',
#  '1',
#  '1',
#  '',
#  '1',
#  '2',
#  '220',
#  '1',
#  '761',
#  '1',
#  '',
#  '20',
#  '1',
#  '12',
#  '1',
#  '2',
#  '56',
#  '',
#  '173',
#  '6',
#  '1',
#  '2',
#  '1',
# ...

# %%
df = pd.DataFrame({'Comment':sp1,'Time':t,'Up Vote':u})
df
# Out:
#                                                Comment                   Time  \
# 0    Separated by Countries but united by music 🇮🇳🇵...           3 months ago
# 1    This song is highly addictive..love from India 🇮🇳              1 day ago
# 2    Addicted to this songLots of Love from INDIA🇮🇳...            5 hours ago
# 3    When this song was trending, i didn't like it ...           20 hours ago
# 4    I'm listening now but I'll listen for the whol...           17 hours ago
# ..                                                 ...                    ...
# 495              Dude awesome Love from India 🇮🇳🇮🇳🇮🇳🇮🇳            2 hours ago
# 496  Since discovering Nusrat Sahab’s music years a...  4 months ago (edited)
# 497                                   Best song ever ️           23 hours ago
# 498                  I am just addicted to this song               2 days ago
# 499        It was nice it catch in my heart 20 to 30 %              1 day ago
#
#     Up Vote
# 0      2.8K
# ...

# %% [markdown]
# 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews,
# overall reviews, privates from price, dorms from price, facilities and property description

# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_7528\437299702.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\prath\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
url = 'https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2022-07-27&to=2022-07-30&guests=2&HostelNumber=&page=1'
driver.get(url)

# %%
hotel = driver.find_elements(By.XPATH,'//h2[@class="title title-6"]')
len(hotel)
# Out:
# 30

# %%
Hotel_name=[]

for i in hotel:
    Hotel_name.append(i.text)
Hotel_name
# Out:
# ['Palmers Lodge - Swiss Cottage',
#  'Selina Camden',
#  "St Christopher's Village",
#  "Wombat's City Hostel London",
#  'Generator London',
#  'Urbany Hostel London',
#  'Safestay London Elephant & Castle',
#  'Smart Russell Square Hostel',
#  'No.8 Seven Sisters',
#  'London Backpackers',
#  'Safestay London Kensington Holland Park',
#  "St Christopher's Inn - London Bridge",
#  'Phoenix Hostel',
#  'Smart Hyde Park View Hostel',
#  'Queen Elizabeth Chelsea',
#  'Hostel One Notting Hill',
#  "St Christopher's Hammersmith",
#  "St Christopher's Camden",
#  "St Christopher's Inn - Liverpool Street",
#  'London Waterloo Hostel',
#  'PubLove @ The White Ferry, Victoria',
#  'Clink261',
#  "St Christopher's Greenwich",
#  'PubLove @ The Steam Engine, Waterloo',
#  "St Christopher's Shepherds Bush",
#  'PubLove @ The Rose & Crown',
#  'Astor Victoria',
#  'PubLove @ The Exmouth Arms, Euston',
#  'PubLove @ The Crown, Battersea',
#  'Park Villa']

# %%
Dis=[]

for i in driver.find_elements(By.XPATH,'//span[@class="description"]'):
    Dis.append((i.text).replace("Hostel -","").replace("from city centre",""))
len(Dis)
# Out:
# 30

# %%
Dis
# Out:
# [' 6.5km ',
#  ' 5.5km ',
#  ' 1.8km ',
#  ' 3.6km ',
#  ' 3km ',
#  ' 5.4km ',
#  ' 1.7km ',
#  ' 2.6km ',
#  ' 9km ',
#  ' 11.9km ',
#  ' 5.9km ',
#  ' 1.8km ',
#  ' 4.2km ',
#  ' 5km ',
#  ' 5.7km ',
#  ' 5.5km ',
#  ' 7.5km ',
#  ' 4.3km ',
#  ' 3.2km ',
#  ' 0.7km ',
#  ' 2.4km ',
#  ' 3.2km ',
#  ' 7.6km ',
#  ' 0.5km ',
#  ' 7km ',
#  ' 1.6km ',
#  ' 1.8km ',
#  ' 3.4km ',
#  ' 4.7km ',
#  ' 6.3km ']

# %%
R=[]

for i in driver.find_elements(By.XPATH,'//div[@class="score orange big"]'):
    R.append((i.text))
len(R)
# Out:
# 30

# %%
R
# Out:
# ['8.8',
#  '8.6',
#  '8.1',
#  '9.1',
#  '7.7',
#  '9.3',
#  '7.0',
#  '7.3',
#  '6.2',
#  '8.1',
#  '6.5',
#  '8.3',
#  '7.6',
#  '8.0',
#  '6.7',
#  '9.2',
#  '7.9',
#  '8.4',
#  '8.7',
#  '6.3',
#  '8.1',
#  '7.9',
#  '6.8',
#  '8.4',
#  '7.3',
#  '8.0',
#  '7.7',
#  '7.0',
#  '6.6',
#  '7.9']

# %%
TR=[]

for i in driver.find_elements(By.XPATH,'//div[@class="reviews"]'):
    TR.append((i.text).replace("Total Reviews",""))
len(TR)
# Out:
# 30

# %%
TR
# Out:
# ['15481 ',
#  '33 ',
#  '11380 ',
#  '13852 ',
#  '7056 ',
#  '410 ',
#  '4405 ',
#  '9701 ',
#  '3817 ',
#  '4290 ',
#  '1267 ',
#  '3334 ',
#  '3673 ',
#  '4575 ',
#  '3303 ',
#  '1424 ',
#  '4073 ',
#  '3810 ',
#  '420 ',
#  '2508 ',
#  '270 ',
#  '109 ',
#  '3220 ',
#  '294 ',
#  '699 ',
#  '139 ',
#  '14782 ',
#  '1034 ',
#  '255 ',
#  '873 ']

# %%
p=[]

for i in driver.find_elements(By.XPATH,'//div[@class="price-col"]'):
    p.append((i.text).replace("Dorms From\n","").replace("\n"," "))
len(p)
# Out:
# 60

# %%
p
# Out:
# ['No Privates Available',
#  'Rs2425',
#  'Privates From Rs25499',
#  'Rs11443.89 Rs9727',
#  'No Privates Available',
#  'Rs2426.1 Rs2183',
#  'Privates From Rs19919.86 Rs16533',
#  'Rs5097.69 Rs3823',
#  'Privates From Rs10580',
#  'Rs3131',
#  'Privates From Rs17250',
#  'Rs4261',
#  'No Privates Available',
#  'Rs2333',
#  'No Privates Available',
#  'Rs2986',
#  'No Privates Available',
#  'Rs1403',
#  'No Privates Available',
#  'Rs2333',
#  'No Privates Available',
#  'Rs1786',
#  'No Privates Available',
#  'Rs2334.37 Rs2101',
#  'No Privates Available',
#  'Rs3104.19 Rs2949',
#  'Privates From Rs14409',
#  'Rs2378',
#  'No Privates Available',
#  'Rs2048',
#  'Privates From Rs19103',
#  'Rs4721',
#  'No Privates Available',
#  'Rs2057.01 Rs1851',
#  'No Privates Available',
#  'Rs2973.33 Rs2676',
#  'No Privates Available',
#  'Rs3825.66 Rs3443',
#  'Privates From Rs14473',
#  'Rs4191',
#  'No Privates Available',
#  'Rs5760',
#  'No Privates Available',
#  'Rs2908',
# ...

# %%
D = p[0:60:2]
D
# Out:
# ['No Privates Available',
#  'Privates From Rs25499',
#  'No Privates Available',
#  'Privates From Rs19919.86 Rs16533',
#  'Privates From Rs10580',
#  'Privates From Rs17250',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'Privates From Rs14409',
#  'No Privates Available',
#  'Privates From Rs19103',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'Privates From Rs14473',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available']

# %%
len(D)
# Out:
# 30

# %%
d = p[1:60:2]
d
# Out:
# ['Rs2425',
#  'Rs11443.89 Rs9727',
#  'Rs2426.1 Rs2183',
#  'Rs5097.69 Rs3823',
#  'Rs3131',
#  'Rs4261',
#  'Rs2333',
#  'Rs2986',
#  'Rs1403',
#  'Rs2333',
#  'Rs1786',
#  'Rs2334.37 Rs2101',
#  'Rs3104.19 Rs2949',
#  'Rs2378',
#  'Rs2048',
#  'Rs4721',
#  'Rs2057.01 Rs1851',
#  'Rs2973.33 Rs2676',
#  'Rs3825.66 Rs3443',
#  'Rs4191',
#  'Rs5760',
#  'Rs2908',
#  'Rs1736.63 Rs1563',
#  'Rs5696',
#  'Rs2227.69 Rs2005',
#  'Rs5152',
#  'Rs2112',
#  'Rs4736',
#  'Rs4128',
#  'Rs4858']

# %%
len(d)
# Out:
# 30

# %%
f=[]

for i in driver.find_elements(By.XPATH,'//div[@class="facilities-label facilities"]'):
    f.append((i.text))
len(f)
# Out:
# 30

# %%
f
# Out:
# ['Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFree Breakfast\nFollows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
# ...

# %%
l=[]

for i in driver.find_elements(By.XPATH,'//div[@class="staff"]'):
    l.append((i.text).replace("Staff",""))
len(l)
# Out:
# 30

# %%
l
# Out:
# ['Superb ',
#  'Superb ',
#  'Superb ',
#  'Superb ',
#  'Marvellous ',
#  'Superb ',
#  'Brilliant ',
#  'Marvellous ',
#  'Marvellous ',
#  'Superb ',
#  'Brilliant ',
#  'Superb ',
#  'Superb ',
#  'Superb ',
#  'Marvellous ',
#  'Superb ',
#  'Superb ',
#  'Superb ',
#  'Superb ',
#  'Marvellous ',
#  'Superb ',
#  'Superb ',
#  'Brilliant ',
#  'Superb ',
#  'Superb ',
#  'Superb ',
#  'Superb ',
#  'Marvellous ',
#  'Brilliant ',
#  'Superb ']

# %%
x=[]

for i in driver.find_elements(By.XPATH,'//div[@class="rating-factors prop-card-tablet rating-factors small"]'):
    x.append((i.text).replace("\n"," and "))
len(x)
# Out:
# 30

# %%
x
# Out:
# ['Perfect Location and Superb Staff and Fantastic Cleanliness',
#  'Perfect Location and Superb Staff and Fantastic Cleanliness',
#  'Perfect Location and Superb Staff and Excellent Cleanliness',
#  'Perfect Location and Superb Staff and Fantastic Cleanliness',
#  'Perfect Location and Marvellous Staff and Awesome Cleanliness',
#  'Perfect Location and Superb Staff and Fantastic Cleanliness',
#  'Wonderful Location and Brilliant Staff and Awesome Cleanliness',
#  'Perfect Location and Marvellous Staff and Awesome Cleanliness',
#  'Great Location and Marvellous Staff',
#  'Wonderful Location and Superb Staff and Excellent Cleanliness',
#  'Wonderful Location and Brilliant Staff',
#  'Perfect Location and Superb Staff and Excellent Cleanliness',
#  'Perfect Location and Superb Staff and Awesome Cleanliness',
#  'Perfect Location and Superb Staff and Excellent Cleanliness',
#  'Wonderful Location and Marvellous Staff',
#  'Perfect Location and Superb Staff and Fantastic Cleanliness',
# ...

# %%
df = pd.DataFrame({'Hostel Name':Hotel_name, 'Distance from city centre':Dis, 'Rating':R, 'Total reviews, ':TR, 'Privates from price':D, 'Dorms from price':d, 'Facilities':f, 'Property description':x})
df
# Out:
#                                 Hostel Name Distance from city centre Rating  \
# 0             Palmers Lodge - Swiss Cottage                    6.5km     8.8
# 1                             Selina Camden                    5.5km     8.6
# 2                  St Christopher's Village                    1.8km     8.1
# 3               Wombat's City Hostel London                    3.6km     9.1
# 4                          Generator London                      3km     7.7
# 5                      Urbany Hostel London                    5.4km     9.3
# 6         Safestay London Elephant & Castle                    1.7km     7.0
# 7               Smart Russell Square Hostel                    2.6km     7.3
# 8                        No.8 Seven Sisters                      9km     6.2
# 9                        London Backpackers                   11.9km     8.1
# 10  Safestay London Kensington Holland Park                    5.9km     6.5
# ...
